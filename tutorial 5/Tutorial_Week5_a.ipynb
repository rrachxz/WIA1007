# %%
import pandas as pd

# %%
df = pd.read_csv("data/salary.csv")

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data Science/Dataset/salary.csv')#, encoding='utf-8'

# %%
df.head() # print first 5 rows
# Out:
#    Unnamed: 0                Timestamp How old are you?  \
# 0           0  2021-04-27 11:02:09.743            25-34
# 1           1  2021-04-27 11:02:21.562            25-34
# 2           2  2021-04-27 11:02:38.125            25-34
# 3           3  2021-04-27 11:02:40.643            25-34
# 4           4  2021-04-27 11:02:41.793            25-34
#
#    What industry do you work in?                                 Job title  \
# 0   Education (Higher Education)        Research and Instruction Librarian
# 1              Computing or Tech  Change & Internal Communications Manager
# 2  Accounting, Banking & Finance                      Marketing Specialist
# 3                     Nonprofits                           Program Manager
# 4  Accounting, Banking & Finance                        Accounting Manager
#
#   If your job title needs additional context, please clarify here:  \
# 0                                                NaN
# ...

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Timestamp', 'How old are you?',
#        'What industry do you work in?', 'Job title',
#        'If your job title needs additional context, please clarify here:',
#        'What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)',
#        'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.',
#        'Please indicate the currency',
#        'If "Other," please indicate the currency here: ',
#        'If your income needs additional context, please provide it here:',
#        'What country do you work in?',
#        'If you're in the U.S., what state do you work in?',
#        'What city do you work in?',
# ...

# %%
df = df.rename(columns={
    'Unnamed: 0': 'USERID',
    'Timestamp': 'Timestamp',
    'How old are you?': 'Age',
    'What industry do you work in?': 'Industry',
    'Job title': 'Job title',
    'If your job title needs additional context, please clarify here:': 'Job title context',
    'What is your annual salary? (You\'ll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)': 'Salary',
    'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.': 'Compensation',
    'Please indicate the currency': 'Currency',
    'If "Other," please indicate the currency here: ': 'Other currency',
    'If your income needs additional context, please provide it here:': 'Salary context',
    'What country do you work in?': 'Country',
    'If you\'re in the U.S., what state do you work in?': 'State',
    'What city do you work in?': 'City',
    'How many years of professional work experience do you have overall?': 'Overall years of experience',
    'How many years of professional work experience do you have in your field?': 'Years of experience in current job',
    'What is your highest level of education completed?': 'Education level',
    'What is your gender?': 'Gender',
    'What is your race? (Choose all that apply.)': 'Race'
})

# %%
df.head() # print first 5 rows
# Out:
#    USERID                Timestamp    Age                       Industry  \
# 0       0  2021-04-27 11:02:09.743  25-34   Education (Higher Education)
# 1       1  2021-04-27 11:02:21.562  25-34              Computing or Tech
# 2       2  2021-04-27 11:02:38.125  25-34  Accounting, Banking & Finance
# 3       3  2021-04-27 11:02:40.643  25-34                     Nonprofits
# 4       4  2021-04-27 11:02:41.793  25-34  Accounting, Banking & Finance
#
#                                   Job title Job title context  Salary  \
# 0        Research and Instruction Librarian               NaN   55000
# 1  Change & Internal Communications Manager               NaN   54600
# 2                      Marketing Specialist               NaN   34000
# 3                           Program Manager               NaN   62000
# 4                        Accounting Manager               NaN   60000
#
#    Compensation Currency Other currency Salary context         Country  \
# ...

# %%
print(df['Salary'].dtype)
# Out:
# int64

# %%
# Convert "Salary" string to integers
df['Salary'] = df['Salary'].replace(',', '', regex=True)
# This replaces the comma ',' in 55,000 to 55000

df['Salary'] = df['Salary'].astype(int)
# This converts the column datatypes from object to numbers, in this case integer

df.head()
# This displays the first 5 rows to verify the conversion
# Out:
#    USERID                Timestamp    Age                       Industry  \
# 0       0  2021-04-27 11:02:09.743  25-34   Education (Higher Education)
# 1       1  2021-04-27 11:02:21.562  25-34              Computing or Tech
# 2       2  2021-04-27 11:02:38.125  25-34  Accounting, Banking & Finance
# 3       3  2021-04-27 11:02:40.643  25-34                     Nonprofits
# 4       4  2021-04-27 11:02:41.793  25-34  Accounting, Banking & Finance
#
#                                   Job title Job title context  Salary  \
# 0        Research and Instruction Librarian               NaN   55000
# 1  Change & Internal Communications Manager               NaN   54600
# 2                      Marketing Specialist               NaN   34000
# 3                           Program Manager               NaN   62000
# 4                        Accounting Manager               NaN   60000
#
#    Compensation Currency Other currency Salary context         Country  \
# ...

# %%
# Use df.info to identify which columns has a lot of missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28180 entries, 0 to 28179
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   USERID                              28180 non-null  int64
#  1   Timestamp                           28180 non-null  object
#  2   Age                                 28180 non-null  object
#  3   Industry                            28099 non-null  object
#  4   Job title                           28178 non-null  object
#  5   Job title context                   7284 non-null   object
#  6   Salary                              28180 non-null  int64
#  7   Compensation                        20824 non-null  float64
#  8   Currency                            28180 non-null  object
#  9   Other currency                      217 non-null    object
#  10  Salary context                      3050 non-null   object
# ...

# %%
missing_compensation = df['Compensation'].isna().sum()
print(f"Number of rows with missing values in 'Compensation' column: {missing_compensation}")
# Out:
# Number of rows with missing values in 'Compensation' column: 7356

# %%
def missing_values_summary(df):
    """
    Returns each column name with the number of missing values

    Parameters:
    df (pd.DataFrame): Input dataframe

    Returns:
    pd.Series: Column names with missing value counts
    """
    missing_counts = df.isna().sum()
    return missing_counts[missing_counts > 0]  # Return only columns with missing values

# Usage
missing_values = missing_values_summary(df)
print("Columns with missing values:")
print(missing_values)
# Out:
# Columns with missing values:
# Industry                81
# Job title                2
# Job title context    20896
# Compensation          7356
# Other currency       27963
# Salary context       25130
# State                 5056
# City                    82
# Education level        236
# Gender                 182
# Race                   190
# dtype: int64

# %%
# Drop columns 'Job title context', 'Other currency', 'Salary context'
df = df.drop(['Job title context', 'Other currency', 'Salary context'], axis=1)

# Check using df.head()
df.head()
# Out:
#    USERID                Timestamp    Age                       Industry  \
# 0       0  2021-04-27 11:02:09.743  25-34   Education (Higher Education)
# 1       1  2021-04-27 11:02:21.562  25-34              Computing or Tech
# 2       2  2021-04-27 11:02:38.125  25-34  Accounting, Banking & Finance
# 3       3  2021-04-27 11:02:40.643  25-34                     Nonprofits
# 4       4  2021-04-27 11:02:41.793  25-34  Accounting, Banking & Finance
#
#                                   Job title  Salary  Compensation Currency  \
# 0        Research and Instruction Librarian   55000           0.0      USD
# 1  Change & Internal Communications Manager   54600        4000.0      GBP
# 2                      Marketing Specialist   34000           NaN      USD
# 3                           Program Manager   62000        3000.0      USD
# 4                        Accounting Manager   60000        7000.0      USD
#
# ...

# %% [markdown]
# 1.2 Dropping missing values
# We can drop missing values here using dropna() function.
# If we do dropna() without specifying any parameter, it will drop rows that has even 1 missing values
# If we do dropna(thresh=2) it will drop rows that has more than 2 missing values
# If we do dropna(how=all) it will drop only rows where all values are missing

# %%
# Number of rows before
rows_before = len(df)
print(f"Rows before: {rows_before}")

# Drop rows with any missing values
df = df.dropna()

# Number of rows after
rows_after = len(df)
print(f"Rows after: {rows_after}")
print(f"Rows dropped: {rows_before - rows_after}")

# Check the result
df.head()
# Out:
# Rows before: 28180
# Rows after: 17041
# Rows dropped: 11139
#    USERID                Timestamp    Age                       Industry  \
# 0       0  2021-04-27 11:02:09.743  25-34   Education (Higher Education)
# 3       3  2021-04-27 11:02:40.643  25-34                     Nonprofits
# 4       4  2021-04-27 11:02:41.793  25-34  Accounting, Banking & Finance
# 6       6  2021-04-27 11:02:50.507  25-34                     Publishing
# 8       8  2021-04-27 11:03:01.045  45-54              Computing or Tech
#
#                             Job title  Salary  Compensation Currency  \
# 0  Research and Instruction Librarian   55000           0.0      USD
# 3                     Program Manager   62000        3000.0      USD
# 4                  Accounting Manager   60000        7000.0      USD
# 6                Publishing Assistant   33000        2000.0      USD
# 8                     Systems Analyst  112000       10000.0      USD
#
# ...

# %%
# Number of rows before
rows_before = len(df)
print(f"Rows before: {rows_before}")

# Drop rows with more than 2 missing values
df = df.dropna(thresh=2)

# Number of rows after
rows_after = len(df)
print(f"Rows after: {rows_after}")
print(f"Rows dropped: {rows_before - rows_after}")

# Check the result
df.head()
# Out:
# Rows before: 17041
# Rows after: 17041
# Rows dropped: 0
#    USERID                Timestamp    Age                       Industry  \
# 0       0  2021-04-27 11:02:09.743  25-34   Education (Higher Education)
# 3       3  2021-04-27 11:02:40.643  25-34                     Nonprofits
# 4       4  2021-04-27 11:02:41.793  25-34  Accounting, Banking & Finance
# 6       6  2021-04-27 11:02:50.507  25-34                     Publishing
# 8       8  2021-04-27 11:03:01.045  45-54              Computing or Tech
#
#                             Job title  Salary  Compensation Currency  \
# 0  Research and Instruction Librarian   55000           0.0      USD
# 3                     Program Manager   62000        3000.0      USD
# 4                  Accounting Manager   60000        7000.0      USD
# 6                Publishing Assistant   33000        2000.0      USD
# 8                     Systems Analyst  112000       10000.0      USD
#
# ...

# %%
# Check for each columns. Example is 'Gender'
# Write a code that prints out each columns and their number of unique items
print('--Columns and their number of unique items--')
for column in df.columns:
    n_unique = df[column].nunique()
    print(f'{column} : {n_unique}')
# Out:
# --Columns and their number of unique items--
# USERID : 17041
# Timestamp : 17041
# Age : 7
# Industry : 842
# Job title : 9429
# Salary : 2396
# Compensation : 751
# Currency : 7
# Country : 116
# State : 121
# City : 3117
# Overall years of experience : 8
# Years of experience in current job : 8
# Education level : 6
# Gender : 5
# Race : 41

# %%
# Check the unique items for Gender
print('\n--Unique items in Gender column--')
print(df['Gender'].unique())
# Out:
# --Unique items in Gender column--
# ['Woman' 'Man' 'Non-binary' 'Other or prefer not to answer'
#  'Prefer not to answer']

# %%
# Remove redundancy by using df.replace()
# Standardize the gender values based on your actual data
df['Gender'] = df['Gender'].replace({
    'Woman': 'Female',
    'Man': 'Male',
    'Non-binary': 'Other',
    'Other or prefer not to answer': 'Other',
    'Prefer not to answer': 'Other'
})

# %%
# Check whether the values have been replaced or not
print('\n--Gender values after replacement--')
print(df['Gender'].unique())
# Out:
# --Gender values after replacement--
# ['Female' 'Male' 'Other']
